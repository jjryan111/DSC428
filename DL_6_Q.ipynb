# %% [markdown]
# <a href="https://colab.research.google.com/github/hbisgin/DeepLearning/blob/main/DL_6_Q.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# %pip install iprogress

# %%
import sys
# sys.path.append('/content/drive/MyDrive/DATA/')
sys.path.append('../Data/')

# %%
# %pip install ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in /usr/local/Cellar/jupyterlab/4.0.10/libexec/lib/python3.12/site-packages (8.1.8)
# Requirement already satisfied: comm>=0.1.3 in /usr/local/Cellar/jupyterlab/4.0.10/libexec/lib/python3.12/site-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: ipython>=6.1.0 in /usr/local/opt/ipython/libexec/lib/python3.12/site-packages (from ipywidgets) (8.19.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/opt/ipython/libexec/lib/python3.12/site-packages (from ipywidgets) (5.14.0)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /usr/local/Cellar/jupyterlab/4.0.10/libexec/lib/python3.12/site-packages (from ipywidgets) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /usr/local/Cellar/jupyterlab/4.0.10/libexec/lib/python3.12/site-packages (from ipywidgets) (3.0.16)
# Requirement already satisfied: decorator in /usr/local/opt/ipython/libexec/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /usr/local/opt/ipython/libexec/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /usr/local/opt/ipython/libexec/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /usr/local/opt/ipython/libexec/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /usr/local/opt/pygments/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (2.17.2)
# Requirement already satisfied: stack-data in /usr/local/opt/ipython/libexec/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in /usr/local/opt/ipython/libexec/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/opt/ipython/libexec/lib/python3.12/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/opt/ipython/libexec/lib/python3.12/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/opt/ipython/libexec/lib/python3.12/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.12)
# Requirement already satisfied: executing>=1.2.0 in /usr/local/opt/ipython/libexec/lib/python3.12/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /usr/local/opt/ipython/libexec/lib/python3.12/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in /usr/local/opt/ipython/libexec/lib/python3.12/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/opt/six/lib/python3.12/site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
#
# [notice] A new release of pip is available: 23.3.2 -> 26.0
# [notice] To update, run: /usr/local/Cellar/jupyterlab/4.0.10/libexec/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import *
from idlmam import *
from tqdm.notebook import tqdm #not necessary
# Out:
# /Users/jj/PyProjects/DSC428/DeepLearning/../Data/idlmam.py:7: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import time

# %%
def train_simple_network(model, loss_func, training_loader, epochs=20, device="cpu"):
    optimizer = torch.optim.SGD(model.parameters(), lr=0.001)

    model.to(device)

    for epoch in tqdm(range(epochs), desc="Epoch"):
        model = model.train()
        running_loss = 0.0

        for inputs, labels in tqdm(training_loader, desc="Batch", leave=False):
            inputs = moveTo(inputs, device)
            labels = moveTo(labels, device)

            optimizer.zero_grad()

            y_hat = model(inputs)

            loss = loss_func(y_hat, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

# %%
X = np.linspace(0, 20, num=200)
y = X + np.sin(X)*2 + np.random.normal(size=X.shape)
sns.scatterplot(x=X, y=y)
# Out:
# <Axes: >

# %% [markdown]
# Dataset

# %%
class Simple1DRegressionDataset(Dataset):

    def __init__(self, X, y):
        super(Simple1DRegressionDataset, self).__init__()
        self.X = X.reshape(-1,1)
        self.y = y.reshape(-1,1)


    def __getitem__(self, index):
        return torch.tensor(self.X[index,:], dtype=torch.float32), torch.tensor(self.y[index], dtype=torch.float32)

    def __len__(self):
        return self.X.shape[0]

# %% [markdown]
# DataLoader

# %%
training_loader = DataLoader(Simple1DRegressionDataset(X, y), shuffle=True)

# %%
xb, yb = next(iter(training_loader))
print("Batch X:", xb, "shape:", xb.shape)
print("Batch y:", yb, "shape:", yb.shape)
# Out:
# Batch X: tensor([[15.2764]]) shape: torch.Size([1, 1])
# Batch y: tensor([[16.2614]]) shape: torch.Size([1, 1])

# %%
training_loader = DataLoader(Simple1DRegressionDataset(X, y), batch_size=10, shuffle=True)

for batch_idx, (xb, yb) in enumerate(training_loader ):
    print(f"Batch {batch_idx}: X={xb.tolist()}  y={yb.tolist()}")
    if batch_idx == 2:  # show only first 3 batches
        break
# Out:
# Batch 0: X=[[13.266331672668457], [15.67839241027832], [3.2160804271698], [14.371859550476074], [7.83919620513916], [11.155778884887695], [20.0], [16.38191032409668], [4.723618030548096], [12.060301780700684]]  y=[[14.121840476989746], [15.992034912109375], [3.689547538757324], [16.448144912719727], [10.319750785827637], [7.9974045753479], [21.999713897705078], [14.319174766540527], [3.53753399848938], [12.091774940490723]]
# Batch 1: X=[[4.321608066558838], [13.065326690673828], [11.055275917053223], [13.467336654663086], [6.733668327331543], [5.427135467529297], [13.768844604492188], [16.180904388427734], [14.874371528625488], [17.587940216064453]]  y=[[3.408421039581299], [14.960309028625488], [8.249444007873535], [16.26409912109375], [6.961551189422607], [5.213333606719971], [15.528815269470215], [15.457889556884766], [16.403051376342773], [15.65180492401123]]
# Batch 2: X=[[15.979899406433105], [1.9095476865768433], [12.361808776855469], [18.793970108032227], [4.120603084564209], [6.130653381347656], [3.517587900161743], [18.090452194213867], [2.412060260772705], [11.758793830871582]]  y=[[14.916707992553711], [2.908079147338867], [11.888541221618652], [18.008676528930664], [3.7240583896636963], [7.176959991455078], [4.871225833892822], [16.79298973083496], [4.255137920379639], [11.468694686889648]]

# %%
# Batch 16: X=[[8.844221115112305], [5.527637958526611], [8.442211151123047], [17.98995018005371], [1.105527639389038], [11.758793830871582], [9.045226097106934], [17.28643226623535], [13.869346618652344], [14.572864532470703]]  y=[[8.561883926391602], [3.2188620567321777], [8.513754844665527], [15.024678230285645], [2.974393844604492], [11.468694686889648], [11.118329048156738], [17.30905532836914], [16.169166564941406], [16.022743225097656]]
# Batch 17: X=[[7.939698696136475], [7.33668327331543], [18.39196014404297], [0.0], [3.91959810256958], [4.924623012542725], [0.7035176157951355], [16.68341636657715], [1.0050251483917236], [12.763818740844727]]  y=[[10.3478422164917], [8.418838500976562], [18.032360076904297], [-0.6075055599212646], [2.434532403945923], [4.728959560394287], [1.3833438158035278], [14.359490394592285], [2.0688183307647705], [11.23849105834961]]
# Batch 18: X=[[14.67336654663086], [10.552763938903809], [5.226130485534668], [6.532663345336914], [10.753768920898438], [20.0], [19.497488021850586], [3.6180903911590576], [14.874371528625488], [2.7135677337646484]]  y=[[17.699121475219727], [9.551685333251953], [3.0733466148376465], [8.228596687316895], [9.318041801452637], [21.999713897705078], [22.104990005493164], [1.477143406867981], [16.403051376342773], [2.9855268001556396]]
# Batch 19: X=[[8.743718147277832], [4.422110557556152], [15.577889442443848], [18.59296417236328], [5.427135467529297], [3.517587900161743], [6.231155872344971], [1.407035231590271], [5.1256279945373535], [5.929648399353027]]  y=[[10.896475791931152], [2.4053139686584473], [15.877869606018066], [19.574804306030273], [5.213333606719971], [4.871225833892822], [7.672673225402832], [2.8895087242126465], [2.6536715030670166], [6.053799152374268]]

# %%
for epoch in range(10):
    for xb, yb in tqdm(training_loader, desc=f"Epoch {epoch+1}", leave=False):
        pass
# Out:
# Epoch 1:   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 2:   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 3:   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 4:   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 5:   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 6:   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 7:   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 8:   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 9:   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 10:   0%|          | 0/20 [00:00<?, ?it/s]

# %% [markdown]
# #Please generate larger datasets which can be still in the same format (x,y) as in our example. Experiment with different batch sizes along with the tqdm module to observe the progress. You can use the following code block for your code

# %%
functions = [X + np.sin(X)*2 + np.random.normal(size=X.shape), X**2 + np.random.normal(size=X.shape), X**5+ 4*X +2]
loaders = []
for i in range(len(functions)):
    num_samples = 200**(i+1)
    X = np.linspace(0, 20, num=num_samples)
    y = functions[i]
    loaders.append(DataLoader(Simple1DRegressionDataset(X, y), shuffle=True))

# %%
for training_loader in loaders:
    in_features = 1
    out_features = 1
    model = nn.Linear(in_features, out_features)
    
    loss_func = nn.MSELoss() #mean square error (MSE)
    
    #device = torch.device("cuda") # if you are sure you have GPU, otherwise use below
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    train_simple_network(model, loss_func, training_loader, device=device)
# Out:
# Epoch:   0%|          | 0/20 [00:00<?, ?it/s]
# Batch:   0%|          | 0/200 [00:00<?, ?it/s]
# Batch:   0%|          | 0/200 [00:00<?, ?it/s]
# Batch:   0%|          | 0/200 [00:00<?, ?it/s]
# Batch:   0%|          | 0/200 [00:00<?, ?it/s]
# Batch:   0%|          | 0/200 [00:00<?, ?it/s]
# Batch:   0%|          | 0/200 [00:00<?, ?it/s]
# Batch:   0%|          | 0/200 [00:00<?, ?it/s]
# Batch:   0%|          | 0/200 [00:00<?, ?it/s]
# Batch:   0%|          | 0/200 [00:00<?, ?it/s]
# Batch:   0%|          | 0/200 [00:00<?, ?it/s]
# Batch:   0%|          | 0/200 [00:00<?, ?it/s]
# Batch:   0%|          | 0/200 [00:00<?, ?it/s]
# Batch:   0%|          | 0/200 [00:00<?, ?it/s]
# Batch:   0%|          | 0/200 [00:00<?, ?it/s]
# Batch:   0%|          | 0/200 [00:00<?, ?it/s]
# Batch:   0%|          | 0/200 [00:00<?, ?it/s]
# Batch:   0%|          | 0/200 [00:00<?, ?it/s]
# Batch:   0%|          | 0/200 [00:00<?, ?it/s]
# Batch:   0%|          | 0/200 [00:00<?, ?it/s]
# Batch:   0%|          | 0/200 [00:00<?, ?it/s]
# Epoch:   0%|          | 0/20 [00:00<?, ?it/s]
# Batch:   0%|          | 0/40000 [00:00<?, ?it/s]
# Batch:   0%|          | 0/40000 [00:00<?, ?it/s]
# Batch:   0%|          | 0/40000 [00:00<?, ?it/s]
# Batch:   0%|          | 0/40000 [00:00<?, ?it/s]
# Batch:   0%|          | 0/40000 [00:00<?, ?it/s]
# Batch:   0%|          | 0/40000 [00:00<?, ?it/s]
# Batch:   0%|          | 0/40000 [00:00<?, ?it/s]
# Batch:   0%|          | 0/40000 [00:00<?, ?it/s]
# Batch:   0%|          | 0/40000 [00:00<?, ?it/s]
# Batch:   0%|          | 0/40000 [00:00<?, ?it/s]
# Batch:   0%|          | 0/40000 [00:00<?, ?it/s]
# Batch:   0%|          | 0/40000 [00:00<?, ?it/s]
# Batch:   0%|          | 0/40000 [00:00<?, ?it/s]
# Batch:   0%|          | 0/40000 [00:00<?, ?it/s]
# Batch:   0%|          | 0/40000 [00:00<?, ?it/s]
# Batch:   0%|          | 0/40000 [00:00<?, ?it/s]
# Batch:   0%|          | 0/40000 [00:00<?, ?it/s]
# Batch:   0%|          | 0/40000 [00:00<?, ?it/s]
# Batch:   0%|          | 0/40000 [00:00<?, ?it/s]
# Batch:   0%|          | 0/40000 [00:00<?, ?it/s]
# Epoch:   0%|          | 0/20 [00:00<?, ?it/s]
# Batch:   0%|          | 0/8000000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[21], line 10
#       8 #device = torch.device("cuda") # if you are sure you have GPU, otherwise use below
#       9 device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# ---> 10 train_simple_network(model, loss_func, training_loader, device=device)
#
# Cell In[5], line 10, in train_simple_network(model, loss_func, training_loader, epochs, device)
#       7 model = model.train()
#       8 running_loss = 0.0
# ---> 10 for inputs, labels in tqdm(training_loader, desc="Batch", leave=False):
#      11     inputs = moveTo(inputs, device)
#      12     labels = moveTo(labels, device)
#
# File /usr/local/Cellar/jupyterlab/4.0.10/libexec/lib/python3.12/site-packages/tqdm/notebook.py:249, in tqdm_notebook.__iter__(self)
#     247 try:
#     248     it = super(tqdm_notebook, self).__iter__()
# --> 249     for obj in it:
#     250         # return super(tqdm...) will not catch exception
#     251         yield obj
#     252 # NB: except ... [ as ...] breaks IPython async KeyboardInterrupt
#
# File /usr/local/Cellar/jupyterlab/4.0.10/libexec/lib/python3.12/site-packages/tqdm/std.py:1182, in tqdm.__iter__(self)
#    1179 time = self._time
#    1181 try:
# -> 1182     for obj in iterable:
#    1183         yield obj
#    1184         # Update and possibly print the progressbar.
#    1185         # Note: does not call self.update(1) for speed optimisation.
#
# File /usr/local/Cellar/jupyterlab/4.0.10/libexec/lib/python3.12/site-packages/torch/utils/data/dataloader.py:631, in _BaseDataLoaderIter.__next__(self)
#     628 if self._sampler_iter is None:
#     629     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630     self._reset()  # type: ignore[call-arg]
# --> 631 data = self._next_data()
#     632 self._num_yielded += 1
#     633 if self._dataset_kind == _DatasetKind.Iterable and \
#     634         self._IterableDataset_len_called is not None and \
#     635         self._num_yielded > self._IterableDataset_len_called:
#
# File /usr/local/Cellar/jupyterlab/4.0.10/libexec/lib/python3.12/site-packages/torch/utils/data/dataloader.py:675, in _SingleProcessDataLoaderIter._next_data(self)
#     673 def _next_data(self):
#     674     index = self._next_index()  # may raise StopIteration
# --> 675     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     676     if self._pin_memory:
#     677         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File /usr/local/Cellar/jupyterlab/4.0.10/libexec/lib/python3.12/site-packages/torch/utils/data/_utils/fetch.py:51, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# Cell In[7], line 10, in Simple1DRegressionDataset.__getitem__(self, index)
#       9 def __getitem__(self, index):
# ---> 10     return torch.tensor(self.X[index,:], dtype=torch.float32), torch.tensor(self.y[index], dtype=torch.float32)
#
# IndexError: index 4667240 is out of bounds for axis 0 with size 40000
