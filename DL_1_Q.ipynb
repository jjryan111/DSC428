# %% [markdown]
# <a href="https://colab.research.google.com/github/hbisgin/DeepLearning/blob/main/DL_1_Q.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Random Forest Example on MNIST data set**

# %% [markdown]
# #import necessary libraries and download the data from online repository

# %%
# %pip install scikit-learn xgboost
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/Cellar/jupyterlab/4.0.10/libexec/lib/python3.12/site-packages (1.8.0)
# Collecting xgboost
#   Downloading xgboost-3.1.3-py3-none-macosx_10_15_x86_64.whl.metadata (2.0 kB)
# Requirement already satisfied: numpy>=1.24.1 in /usr/local/lib/python3.12/site-packages (from scikit-learn) (1.26.3)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/Cellar/jupyterlab/4.0.10/libexec/lib/python3.12/site-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.3.0 in /usr/local/Cellar/jupyterlab/4.0.10/libexec/lib/python3.12/site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /usr/local/Cellar/jupyterlab/4.0.10/libexec/lib/python3.12/site-packages (from scikit-learn) (3.6.0)
# Downloading xgboost-3.1.3-py3-none-macosx_10_15_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 10.9 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: xgboost
# Successfully installed xgboost-3.1.3
#
# [notice] A new release of pip is available: 23.3.2 -> 25.3
# [notice] To update, run: /usr/local/Cellar/jupyterlab/4.0.10/libexec/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, ConfusionMatrixDisplay

# Load the full MNIST dataset (28x28 resolution = 784 features)
X, y = fetch_openml('mnist_784', version=1, as_frame=False, return_X_y=True, parser='auto')

# %% [markdown]
# #CREATE THE SUBSET: 2,000 samples, 784 features each
#
# We use 'stratify' to ensure we get exactly ~200 of each digit (0-9)

# %%
X_small, _, y_small, _ = train_test_split(X, y, train_size=2000, stratify=y, random_state=42)

# %% [markdown]
# #Preprocessing: Scale pixel values to [0, 1]

# %%
X_small = X_small / 255.0

# %% [markdown]
# #Visualize samples from our subset

# %%
print("Visualizing 28x28 samples from your 2,000-image subset...")
fig, axes = plt.subplots(1, 5, figsize=(12, 3))
for i in range(5):
    axes[i].imshow(X_small[i].reshape(28, 28), cmap='gray')
    axes[i].set_title(f"Label: {y_small[i]}")
    axes[i].axis('off')
plt.show()
# Out:
# Visualizing 28x28 samples from your 2,000-image subset...

# %% [markdown]
# # Split subset into Training (80%) and Testing (20%)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_small, y_small, test_size=0.2, random_state=42
)

# %% [markdown]
# #Train a Traditional ML Model (Random Forest)

# %%
print(f"Training on {len(X_train)} images...")
model = RandomForestClassifier(n_estimators=100, n_jobs=-1, random_state=42)
model.fit(X_train, y_train)
# Out:
# Training on 1600 images...
# RandomForestClassifier(n_jobs=-1, random_state=42)

# %% [markdown]
# #Evaluate our model on the test set

# %%
print("\nResults on the 400-image test set:")
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
# Results on the 400-image test set:
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95        40
#            1       0.95      0.98      0.96        41
#            2       0.85      0.87      0.86        39
#            3       0.85      0.82      0.84        40
#            4       0.97      0.90      0.94        41
#            5       0.79      0.79      0.79        28
#            6       0.90      0.88      0.89        43
#            7       0.91      0.95      0.93        41
#            8       0.90      0.90      0.90        42
#            9       0.90      0.84      0.87        45
#
#     accuracy                           0.90       400
#    macro avg       0.89      0.89      0.89       400
# weighted avg       0.90      0.90      0.90       400

# %% [markdown]
# #Plotting our confusion matrix. Please note that this is multi-class case

# %%
ConfusionMatrixDisplay.from_predictions(y_test, y_pred, cmap='Purples')
plt.title("Confusion Matrix (28x28 Subset)")
plt.show()

# %% [markdown]
# Can you a similar training and test by using XGBOOST?
#
# Please use the code block below to start with.
#
# Please also provide the prediction report and the confusion display, too

# %%
from xgboost import XGBClassifier

#please remember to cast your y labels to int by using astype(int)
xg_X_train, xg_X_test, y_train_raw, y_test_raw = train_test_split(
    X_small, y_small, test_size=0.2, random_state=42
)
xg_y_train = y_train_raw.astype(int)
xg_y_test = y_test_raw.astype(int)
xg_model =  XGBClassifier(
    objective="multi:softprob",   
    num_class=10,                  
    n_estimators=100,
    max_depth=3,
    learning_rate=0.1,
    eval_metric="mlogloss",
    random_state=42
)

# Train
xg_model.fit(xg_X_train, xg_y_train)

# Predict
xg_y_pred = xg_model.predict(xg_X_test)
print("\t==========Results Using XGBoost=============")
print(classification_report(xg_y_test, xg_y_pred))
# Out:
# 	==========Results Using XGBoost=============
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96        40
#            1       0.93      0.95      0.94        41
#            2       0.77      0.85      0.80        39
#            3       0.89      0.78      0.83        40
#            4       0.90      0.93      0.92        41
#            5       0.73      0.79      0.76        28
#            6       0.93      0.86      0.89        43
#            7       0.93      0.95      0.94        41
#            8       0.82      0.88      0.85        42
#            9       0.88      0.78      0.82        45
#
#     accuracy                           0.88       400
#    macro avg       0.87      0.87      0.87       400
# weighted avg       0.88      0.88      0.87       400

# %%
ConfusionMatrixDisplay.from_predictions(xg_y_test, xg_y_pred, cmap='Purples')
plt.title("XGBoost Confusion Matrix (28x28 Subset)")
plt.show()
